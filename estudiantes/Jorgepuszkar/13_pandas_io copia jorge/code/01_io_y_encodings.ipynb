# %% [markdown]
# # IO y Encodings en Pandas
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sonder-art/fdd_p26/blob/main/clase/13_pandas_io/code/01_io_y_encodings.ipynb)
#
# Leer datos es el primer paso de cualquier pipeline. Pandas hace que el caso feliz sea trivial, pero en producción los datos rara vez llegan limpios: separadores raros, encodings incorrectos, JSON anidado, columnas que no necesitas. Este notebook cubre los casos que sí te vas a encontrar.

# %%
# Ejecutar solo si no tienes las librerías instaladas
# En Colab, ejecuta esta celda primero
# %pip install pandas==2.2.3 numpy==1.26.4 pyarrow==17.0.0 chardet==5.2.0 charset-normalizer==3.3.2 openpyxl==3.1.5
# Out:
# Collecting pandas==2.2.3
#   Using cached pandas-2.2.3.tar.gz (4.4 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [196 lines of output]
#       + meson setup /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5 /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/.mesonpy-9bv2tfa5/build -Dbuildtype=release -Db_ndebug=if-release -Db_vscrt=md --vsenv --native-file=/private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/.mesonpy-9bv2tfa5/build/meson-python-native-file.ini
#       The Meson build system
#       Version: 1.2.1
#       Source dir: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5
#       Build dir: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/.mesonpy-9bv2tfa5/build
#       Build type: native build
#       Project name: pandas
#       Project version: 2.2.3
#       C compiler for the host machine: cc (clang 17.0.0 "Apple clang version 17.0.0 (clang-1700.6.3.2)")
#       C linker for the host machine: cc ld64 1230.1
#       C++ compiler for the host machine: c++ (clang 17.0.0 "Apple clang version 17.0.0 (clang-1700.6.3.2)")
#       C++ linker for the host machine: c++ ld64 1230.1
#       Cython compiler for the host machine: cython (cython 3.0.12)
#       Host machine cpu family: aarch64
#       Host machine cpu: aarch64
#       Program python found: YES (/Users/jorgepuszkar/Desktop/fuentes/fdd_p26/.venv/bin/python)
#       Found pkg-config: /opt/homebrew/bin/pkg-config (2.5.1)
#       Run-time dependency python found: YES 3.14
#       Build targets in project: 53
#
#       pandas 2.2.3
#
#         User defined options
#           Native files: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/.mesonpy-9bv2tfa5/build/meson-python-native-file.ini
#           buildtype   : release
#           vsenv       : True
#           b_ndebug    : if-release
#           b_vscrt     : md
#
#       Found ninja-1.13.0.git.kitware.jobserver-pipe-1 at /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-build-env-5_tx1i6k/normal/bin/ninja
#
#       Visual Studio environment is needed to run Ninja. It is recommended to use Meson wrapper:
#       /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-build-env-5_tx1i6k/overlay/bin/meson compile -C .
#       + /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-build-env-5_tx1i6k/normal/bin/ninja
#       [1/151] Generating pandas/_libs/algos_common_helper_pxi with a custom command
#       [2/151] Generating pandas/_libs/khash_primitive_helper_pxi with a custom command
#       [3/151] Generating pandas/_libs/hashtable_func_helper_pxi with a custom command
#       [4/151] Generating pandas/_libs/index_class_helper_pxi with a custom command
#       [5/151] Generating pandas/_libs/intervaltree_helper_pxi with a custom command
#       [6/151] Generating pandas/_libs/algos_take_helper_pxi with a custom command
#       [7/151] Generating pandas/_libs/sparse_op_helper_pxi with a custom command
#       [8/151] Generating pandas/_libs/hashtable_class_helper_pxi with a custom command
#       [9/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/base.pyx
#       [10/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/ccalendar.pyx
#       [11/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/dtypes.pyx
#       [12/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/nattype.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/nattype.pyx:79:0: Global name __nat_unpickle matched from within class scope in contradiction to to Python 'class private name' rules. This may change in a future release.
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/nattype.pyx:79:0: Global name __nat_unpickle matched from within class scope in contradiction to to Python 'class private name' rules. This may change in a future release.
#       [13/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/np_datetime.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [14/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/fields.pyx
#       [15/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/parsing.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [16/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/conversion.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [17/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/strptime.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [18/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/period.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [19/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/timedeltas.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [20/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/offsets.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [21/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/timezones.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [22/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/tzconversion.pyx
#       [23/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/vectorized.pyx
#       [24/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/timestamps.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [25/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/indexing.pyx
#       [26/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/arrays.pyx
#       [27/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/hashing.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [28/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/ops_dispatch.pyx
#       [29/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/missing.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [30/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/internals.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [31/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/ops.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [32/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/properties.pyx
#       [33/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/parsers.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/parsers.pyx:1605:18: noexcept clause is ignored for function returning Python object
#       [34/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/byteswap.pyx
#       [35/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/index.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [36/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/sas.pyx
#       [37/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/reshape.pyx
#       [38/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/lib.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [39/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/interval.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [40/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/testing.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [41/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/join.pyx
#       [42/151] Compiling C object pandas/_libs/tslibs/base.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_base.pyx.c.o
#       [43/151] Compiling C object pandas/_libs/tslibs/ccalendar.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_ccalendar.pyx.c.o
#       [44/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/algos.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [45/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/writers.pyx
#       [46/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/hashtable.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [47/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/groupby.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [48/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/window/indexers.pyx
#       [49/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslib.pyx
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:188:38: noexcept clause is ignored for function returning Python object
#       warning: /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/tslibs/util.pxd:193:40: noexcept clause is ignored for function returning Python object
#       [50/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/window/aggregations.pyx
#       [51/151] Compiling C object pandas/_libs/tslibs/np_datetime.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_np_datetime.pyx.c.o
#       [52/151] Compiling C object pandas/_libs/tslibs/parsing.cpython-314-darwin.so.p/.._src_parser_tokenizer.c.o
#       [53/151] Compiling Cython source /private/var/folders/4j/4nf4zy_93rj_7mqt_s_56d9w0000gn/T/pip-install-j238tlz_/pandas_0dbc8e268f8f4f51ba3901af508a47d5/pandas/_libs/sparse.pyx
#       [54/151] Compiling C object pandas/_libs/tslibs/dtypes.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_dtypes.pyx.c.o
#       [55/151] Compiling C object pandas/_libs/tslibs/nattype.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_nattype.pyx.c.o
#       [56/151] Compiling C object pandas/_libs/tslibs/conversion.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_conversion.pyx.c.o
#       [57/151] Compiling C object pandas/_libs/tslibs/fields.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_fields.pyx.c.o
#       [58/151] Compiling C object pandas/_libs/arrays.cpython-314-darwin.so.p/meson-generated_pandas__libs_arrays.pyx.c.o
#       [59/151] Compiling C object pandas/_libs/tslibs/timezones.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_timezones.pyx.c.o
#       [60/151] Compiling C object pandas/_libs/tslibs/tzconversion.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_tzconversion.pyx.c.o
#       [61/151] Compiling C object pandas/_libs/tslibs/vectorized.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_vectorized.pyx.c.o
#       [62/151] Compiling C object pandas/_libs/tslibs/strptime.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_strptime.pyx.c.o
#       [63/151] Compiling C object pandas/_libs/tslibs/parsing.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_parsing.pyx.c.o
#       [64/151] Compiling C object pandas/_libs/tslibs/period.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_period.pyx.c.o
#       [65/151] Compiling C object pandas/_libs/indexing.cpython-314-darwin.so.p/meson-generated_pandas__libs_indexing.pyx.c.o
#       [66/151] Compiling C object pandas/_libs/hashing.cpython-314-darwin.so.p/meson-generated_pandas__libs_hashing.pyx.c.o
#       [67/151] Compiling C object pandas/_libs/tslibs/timedeltas.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_timedeltas.pyx.c.o
#       [68/151] Compiling C object pandas/_libs/tslibs/timestamps.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_timestamps.pyx.c.o
#       [69/151] Compiling C object pandas/_libs/lib.cpython-314-darwin.so.p/src_parser_tokenizer.c.o
#       [70/151] Compiling C object pandas/_libs/pandas_datetime.cpython-314-darwin.so.p/src_vendored_numpy_datetime_np_datetime.c.o
#       [71/151] Compiling C object pandas/_libs/pandas_datetime.cpython-314-darwin.so.p/src_vendored_numpy_datetime_np_datetime_strings.c.o
#       [72/151] Compiling C object pandas/_libs/pandas_datetime.cpython-314-darwin.so.p/src_datetime_date_conversions.c.o
#       [73/151] Compiling C object pandas/_libs/pandas_datetime.cpython-314-darwin.so.p/src_datetime_pd_datetime.c.o
#       [74/151] Compiling C object pandas/_libs/pandas_parser.cpython-314-darwin.so.p/src_parser_io.c.o
#       [75/151] Compiling C object pandas/_libs/pandas_parser.cpython-314-darwin.so.p/src_parser_tokenizer.c.o
#       [76/151] Compiling C object pandas/_libs/pandas_parser.cpython-314-darwin.so.p/src_parser_pd_parser.c.o
#       [77/151] Compiling C object pandas/_libs/internals.cpython-314-darwin.so.p/meson-generated_pandas__libs_internals.pyx.c.o
#       [78/151] Compiling C object pandas/_libs/parsers.cpython-314-darwin.so.p/src_parser_io.c.o
#       [79/151] Compiling C object pandas/_libs/parsers.cpython-314-darwin.so.p/src_parser_tokenizer.c.o
#       [80/151] Compiling C object pandas/_libs/json.cpython-314-darwin.so.p/src_vendored_ujson_python_ujson.c.o
#       [81/151] Compiling C object pandas/_libs/json.cpython-314-darwin.so.p/src_vendored_ujson_python_objToJSON.c.o
#       [82/151] Compiling C object pandas/_libs/missing.cpython-314-darwin.so.p/meson-generated_pandas__libs_missing.pyx.c.o
#       [83/151] Compiling C object pandas/_libs/json.cpython-314-darwin.so.p/src_vendored_ujson_python_JSONtoObj.c.o
#       [84/151] Compiling C object pandas/_libs/json.cpython-314-darwin.so.p/src_vendored_ujson_lib_ultrajsonenc.c.o
#       [85/151] Compiling C object pandas/_libs/json.cpython-314-darwin.so.p/src_vendored_ujson_lib_ultrajsondec.c.o
#       [86/151] Compiling C object pandas/_libs/ops_dispatch.cpython-314-darwin.so.p/meson-generated_pandas__libs_ops_dispatch.pyx.c.o
#       [87/151] Compiling C object pandas/_libs/properties.cpython-314-darwin.so.p/meson-generated_pandas__libs_properties.pyx.c.o
#       [88/151] Compiling C object pandas/_libs/ops.cpython-314-darwin.so.p/meson-generated_pandas__libs_ops.pyx.c.o
#       [89/151] Compiling C object pandas/_libs/tslibs/offsets.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslibs_offsets.pyx.c.o
#       [90/151] Compiling C object pandas/_libs/sas.cpython-314-darwin.so.p/meson-generated_pandas__libs_sas.pyx.c.o
#       [91/151] Compiling C object pandas/_libs/byteswap.cpython-314-darwin.so.p/meson-generated_pandas__libs_byteswap.pyx.c.o
#       [92/151] Compiling C object pandas/_libs/reshape.cpython-314-darwin.so.p/meson-generated_pandas__libs_reshape.pyx.c.o
#       [93/151] Compiling C object pandas/_libs/index.cpython-314-darwin.so.p/meson-generated_pandas__libs_index.pyx.c.o
#       [94/151] Compiling C object pandas/_libs/lib.cpython-314-darwin.so.p/meson-generated_pandas__libs_lib.pyx.c.o
#       [95/151] Compiling C++ object pandas/_libs/window/aggregations.cpython-314-darwin.so.p/meson-generated_pandas__libs_window_aggregations.pyx.cpp.o
#       FAILED: [code=1] pandas/_libs/window/aggregations.cpython-314-darwin.so.p/meson-generated_pandas__libs_window_aggregations.pyx.cpp.o
#       c++ -Ipandas/_libs/window/aggregations.cpython-314-darwin.so.p -Ipandas/_libs/window -I../../pandas/_libs/window -I../../../../pip-build-env-5_tx1i6k/overlay/lib/python3.14/site-packages/numpy/_core/include -I../../pandas/_libs/include -I/opt/homebrew/opt/python@3.14/Frameworks/Python.framework/Versions/3.14/include/python3.14 -fvisibility=hidden -fvisibility-inlines-hidden -fcolor-diagnostics -DNDEBUG -w -O3 -DNPY_NO_DEPRECATED_API=0 -DNPY_TARGET_VERSION=NPY_1_21_API_VERSION -MD -MQ pandas/_libs/window/aggregations.cpython-314-darwin.so.p/meson-generated_pandas__libs_window_aggregations.pyx.cpp.o -MF pandas/_libs/window/aggregations.cpython-314-darwin.so.p/meson-generated_pandas__libs_window_aggregations.pyx.cpp.o.d -o pandas/_libs/window/aggregations.cpython-314-darwin.so.p/meson-generated_pandas__libs_window_aggregations.pyx.cpp.o -c pandas/_libs/window/aggregations.cpython-314-darwin.so.p/pandas/_libs/window/aggregations.pyx.cpp
#       pandas/_libs/window/aggregations.cpython-314-darwin.so.p/pandas/_libs/window/aggregations.pyx.cpp:1235:10: fatal error: 'ios' file not found
#        1235 | #include "ios"
#             |          ^~~~~
#       1 error generated.
#       [96/151] Compiling C object pandas/_libs/parsers.cpython-314-darwin.so.p/meson-generated_pandas__libs_parsers.pyx.c.o
#       [97/151] Compiling C object pandas/_libs/testing.cpython-314-darwin.so.p/meson-generated_pandas__libs_testing.pyx.c.o
#       [98/151] Compiling C object pandas/_libs/window/indexers.cpython-314-darwin.so.p/meson-generated_pandas__libs_window_indexers.pyx.c.o
#       [99/151] Compiling C object pandas/_libs/writers.cpython-314-darwin.so.p/meson-generated_pandas__libs_writers.pyx.c.o
#       [100/151] Compiling C object pandas/_libs/tslib.cpython-314-darwin.so.p/meson-generated_pandas__libs_tslib.pyx.c.o
#       [101/151] Compiling C object pandas/_libs/interval.cpython-314-darwin.so.p/meson-generated_pandas__libs_interval.pyx.c.o
#       [102/151] Compiling C object pandas/_libs/join.cpython-314-darwin.so.p/meson-generated_pandas__libs_join.pyx.c.o
#       [103/151] Compiling C object pandas/_libs/algos.cpython-314-darwin.so.p/meson-generated_pandas__libs_algos.pyx.c.o
#       [104/151] Compiling C object pandas/_libs/sparse.cpython-314-darwin.so.p/meson-generated_pandas__libs_sparse.pyx.c.o
#       [105/151] Compiling C object pandas/_libs/hashtable.cpython-314-darwin.so.p/meson-generated_pandas__libs_hashtable.pyx.c.o
#       [106/151] Compiling C object pandas/_libs/groupby.cpython-314-darwin.so.p/meson-generated_pandas__libs_groupby.pyx.c.o
#       ninja: build stopped: subcommand failed.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> pandas
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %%
import io
import json
import chardet
import numpy as np
import pandas as pd
from charset_normalizer import from_bytes

# %% [markdown]
# ---
#
# ## Sección 1: CSV — más allá del caso básico
#
# ### El caso feliz
#
# `pd.read_csv()` funciona perfectamente cuando el archivo sigue la convención: comas como separador, encabezado en la primera fila, strings como UTF-8. Pero eso no siempre pasa.

# %%
# io.StringIO simula un archivo en memoria — no necesitas escribir nada al disco
csv_simple = """
nombre,edad,ciudad
Ana,28,CDMX
Luis,34,Guadalajara
María,22,Monterrey
""".strip()

df = pd.read_csv(io.StringIO(csv_simple))
df
# Out:
#   nombre  edad       ciudad
# 0    Ana    28         CDMX
# 1   Luis    34  Guadalajara
# 2  María    22    Monterrey

# %% [markdown]
# ### Separadores: no todo es una coma
#
# El parámetro `sep=` (o `delimiter=`) controla qué carácter separa columnas. Los más comunes son `;` (Europa, Excel en español), `\t` (TSV) y `|` (logs, bases de datos).

# %%
# CSV con punto y coma — muy común en archivos exportados desde Excel en español
csv_puntoycoma = "nombre;sueldo;departamento\nAna;45000;Ingeniería\nLuis;38000;Marketing"

df_sc = pd.read_csv(io.StringIO(csv_puntoycoma), sep=";")
df_sc
# Out:
#   nombre  sueldo departamento
# 0    Ana   45000   Ingeniería
# 1   Luis   38000    Marketing

# %%
# TSV (Tab-Separated Values) — común en exports de bases de datos
csv_tsv = "id\tnombre\tvalor\n1\tProducto A\t99.9\n2\tProducto B\t149.9"

df_tsv = pd.read_csv(io.StringIO(csv_tsv), sep="\t")
df_tsv
# Out:
#    id      nombre  valor
# 0   1  Producto A   99.9
# 1   2  Producto B  149.9

# %%
# Pipe-separated — frecuente en logs y sistemas legacy
csv_pipe = "fecha|evento|usuario\n2026-01-01|login|ana@itam.mx\n2026-01-01|logout|luis@itam.mx"

df_pipe = pd.read_csv(io.StringIO(csv_pipe), sep="|")
df_pipe
# Out:
#         fecha  evento       usuario
# 0  2026-01-01   login   ana@itam.mx
# 1  2026-01-01  logout  luis@itam.mx

# %% [markdown]
# 💡 **Prueba esto:** cambia `sep="|"` por `sep=","` en el último ejemplo y observa qué pasa. Pandas leerá todo como una sola columna.

# %% [markdown]
# ### Archivos sin header o con metadata arriba
#
# Muchos sistemas exportan archivos con líneas de metadata antes de los datos, o sin encabezado. Los parámetros `header=`, `names=` y `skiprows=` manejan estos casos.

# %%
# Archivo con líneas de metadata antes de los datos reales
csv_con_metadata = """
# Reporte mensual de ventas
# Generado: 2026-03-01
# Sistema: ERP v2.1
producto,cantidad,precio
Laptop,5,22000
Monitor,12,8500
Teclado,30,1200
""".strip()

# skiprows salta las primeras N filas antes de buscar el header
df_meta = pd.read_csv(io.StringIO(csv_con_metadata), skiprows=3)
df_meta
# Out:
#   producto  cantidad  precio
# 0   Laptop         5   22000
# 1  Monitor        12    8500
# 2  Teclado        30    1200

# %%
# Archivo sin encabezado — pandas asignaría 0, 1, 2... por defecto
csv_sin_header = "Ana,28,CDMX\nLuis,34,Guadalajara\nMaría,22,Monterrey"

# header=None le dice que no hay fila de encabezado
# names= asigna los nombres que tú quieras
df_sh = pd.read_csv(
    io.StringIO(csv_sin_header),
    #header=None,
    names=["nombre", "edad", "ciudad"]
)
df_sh
# Out:
#   nombre  edad       ciudad
# 0    Ana    28         CDMX
# 1   Luis    34  Guadalajara
# 2  María    22    Monterrey

# %% [markdown]
# 💡 **Prueba esto:** quita `header=None` del ejemplo anterior. ¿Qué pasa con la primera fila?

# %% [markdown]
# ### `usecols=` — leer solo lo que necesitas
#
# Si tienes un CSV con 50 columnas pero solo necesitas 3, leer todo desperdicia memoria. `usecols=` es tu amigo para performance, especialmente con archivos grandes.

# %%
csv_muchas_cols = """
id,nombre,apellido,edad,ciudad,estado,pais,telefono,email,salario,departamento
1,Ana,García,28,CDMX,CDMX,MX,5512345678,ana@co.mx,45000,Ingeniería
2,Luis,Martínez,34,GDL,JAL,MX,3312345678,luis@co.mx,38000,Marketing
3,María,López,22,MTY,NL,MX,8112345678,maria@co.mx,52000,Finanzas
""".strip()

# Solo las columnas que realmente vamos a usar — pandas ni siquiera parsea las demás
df_cols = pd.read_csv(
    io.StringIO(csv_muchas_cols),
    usecols=["nombre", "ciudad", "salario"]
)
df_cols
# Out:
#   nombre ciudad  salario
# 0    Ana   CDMX    45000
# 1   Luis    GDL    38000
# 2  María    MTY    52000

# %%
# También puedes seleccionar por posición (índice de columna)
df_cols_idx = pd.read_csv(
    io.StringIO(csv_muchas_cols),
    usecols=[0, 1, 9]  # id, nombre, salario
)
df_cols_idx
# Out:
#    id nombre  salario
# 0   1    Ana    45000
# 1   2   Luis    38000
# 2   3  María    52000

# %% [markdown]
# ### `dtype=` — no dejes que pandas infiera los tipos
#
# Pandas infiere tipos al leer, pero esa inferencia puede salir mal. El bug clásico: una columna de enteros que tiene al menos un `NaN` se convierte automáticamente a `float64` porque Python int no acepta nulos.

# %%
# El bug: código postal como entero, pero hay un NaN
csv_cp = "nombre,codigo_postal\nAna,06600\nLuis,\nMaría,11000"

df_bug = pd.read_csv(io.StringIO(csv_cp))
print(df_bug.dtypes)
print()
df_bug
# Out:
# nombre               str
# codigo_postal    float64
# dtype: object
#   nombre  codigo_postal
# 0    Ana         6600.0
# 1   Luis            NaN
# 2  María        11000.0

# %%
# El problema: 06600 se convierte a 6600.0 — perdiste el cero inicial
# Solución: forzar dtype=str para mantener el valor original
df_ok = pd.read_csv(
    io.StringIO(csv_cp),
    dtype={"codigo_postal": str}
)
print(df_ok.dtypes)
print()
df_ok
# Out:
# nombre           str
# codigo_postal    str
# dtype: object
#   nombre codigo_postal
# 0    Ana         06600
# 1   Luis           NaN
# 2  María         11000

# %%
# Puedes especificar tipos para múltiples columnas a la vez
csv_tipos = "id,precio,categoria\n1,29.99,A\n2,149.50,B\n3,9.99,A"

df_tipos = pd.read_csv(
    io.StringIO(csv_tipos),
    dtype={"id": np.int32, "precio": np.float32, "categoria": "category"}
)
print(df_tipos.dtypes)
df_tipos
# Out:
# id              int32
# precio        float32
# categoria    category
# dtype: object
#    id  precio categoria
# 0   1   29.99         A
# 1   2  149.50         B
# 2   3    9.99         A

# %% [markdown]
# 💡 **Prueba esto:** agrega `dtype={"id": np.int8}` a un CSV donde id=300. ¿Qué error obtienes? Los tipos enteros tienen límites de tamaño.

# %% [markdown]
# ### `na_values=` — valores nulos personalizados
#
# Pandas reconoce varios strings como `NaN` por defecto (`""`, `"NA"`, `"NaN"`, `"null"`, `"None"`), pero en datos reales aparecen convenciones propias: `"."`, `"-"`, `"99999"`, `"N/A"`, `"ND"`.

# %%
# Dataset con varias convenciones de valores faltantes
csv_nulos = "nombre,edad,ingreso,score\nAna,28,45000,8.5\nLuis,.,38000,N/A\nMaría,22,99999,-\nCarlos,35,52000,ND"

# Sin na_values: pandas solo detecta los nulos estándar
df_sin_na = pd.read_csv(io.StringIO(csv_nulos))
print("Sin na_values:")
print(df_sin_na)
print()

# Con na_values: le decimos exactamente qué strings representan nulos
df_con_na = pd.read_csv(
    io.StringIO(csv_nulos),
    na_values=[".", "-", "99999", "N/A", "ND"]
)
print("Con na_values:")
print(df_con_na)
# Out:
# Sin na_values:
#    nombre edad  ingreso score
# 0     Ana   28    45000   8.5
# 1    Luis    .    38000   NaN
# 2   María   22    99999     -
# 3  Carlos   35    52000    ND
#
# Con na_values:
#    nombre  edad  ingreso  score
# 0     Ana  28.0  45000.0    8.5
# 1    Luis   NaN  38000.0    NaN
# 2   María  22.0      NaN    NaN
# 3  Carlos  35.0  52000.0    NaN

# %% [markdown]
# ### `parse_dates=` — fechas al leer
#
# En lugar de leer fechas como strings y luego convertirlas con `pd.to_datetime()`, puedes pedirle a pandas que lo haga directamente al leer.

# %%
csv_fechas = "evento,fecha_inicio,fecha_fin\nConferencia,2026-03-15,2026-03-17\nTaller,2026-04-01,2026-04-02"

df_fechas = pd.read_csv(
    io.StringIO(csv_fechas),
    parse_dates=["fecha_inicio", "fecha_fin"]  # lista de columnas a parsear como fechas
)
print(df_fechas.dtypes)
print()
df_fechas
# Out:
# evento                     str
# fecha_inicio    datetime64[us]
# fecha_fin       datetime64[us]
# dtype: object
#         evento fecha_inicio  fecha_fin
# 0  Conferencia   2026-03-15 2026-03-17
# 1       Taller   2026-04-01 2026-04-02

# %% [markdown]
# ### Ejercicio 1
#
# Tienes el siguiente CSV (mal formateado como suelen venir de Excel en México):
#
# ```
# # Reporte Q1 2026
# producto;ventas;precio_unitario;fecha_venta
# Laptop;5;22000;15/01/2026
# Monitor;.;8500;20/01/2026
# Teclado;30;ND;25/01/2026
# ```
#
# Lee este CSV de forma que:
# - Salte la línea de metadata
# - Use `;` como separador
# - Trate `.` y `ND` como nulos
# - Solo lea las columnas `producto`, `ventas` y `precio_unitario`

# %%
csv_ejercicio1 = """
# Reporte Q1 2026
producto;ventas;precio_unitario;fecha_venta
Laptop;5;22000;15/01/2026
Monitor;.;8500;20/01/2026
Teclado;30;ND;25/01/2026
""".strip()

# Tu solución aquí
df_ej1 = pd.read_csv(
    io.StringIO(csv_ejercicio1),
    skiprows=1,
    sep=";",
    na_values=[".", "ND"],
    usecols=["producto", "ventas", "precio_unitario"]
    # ... completa los parámetros
)
df_ej1
# Out:
#   producto  ventas  precio_unitario
# 0   Laptop     5.0          22000.0
# 1  Monitor     NaN           8500.0
# 2  Teclado    30.0              NaN

# %% [markdown]
# <details>
# <summary>Ver solución</summary>
#
# ```python
# df_ej1 = pd.read_csv(
#     io.StringIO(csv_ejercicio1),
#     skiprows=1,
#     sep=";",
#     na_values=[".", "ND"],
#     usecols=["producto", "ventas", "precio_unitario"]
# )
# ```
# </details>

# %% [markdown]
# ---
#
# ## Sección 2: Encodings y Mojibake
#
# ### ¿Qué es un encoding?
#
# Un archivo de texto es, en el fondo, una secuencia de bytes. Un **encoding** es el mapa que dice cómo traducir esos bytes a caracteres legibles. Si el archivo se guardó con un encoding y lo lees con otro, obtienes **mojibake** — esa basura de caracteres como `Ã¡` en lugar de `á`.
#
# Los encodings más comunes en datos latinoamericanos:
#
# | Encoding | Alias | Contexto |
# |---|---|---|
# | `utf-8` | — | Estándar universal, soporta todos los idiomas |
# | `latin-1` | `iso-8859-1` | Europa occidental, muy común en archivos viejos |
# | `cp1252` | `windows-1252` | Windows en América/Europa, similar a latin-1 |
# | `utf-8-sig` | — | UTF-8 con BOM (Excel en Windows lo genera) |

# %% [markdown]
# ### Demostración de Mojibake
#
# El mojibake ocurre cuando un archivo guardado en encoding A se lee como si fuera encoding B. Vamos a replicarlo con bytes reales.

# %%
# String original con acentos — texto real en español
texto_original = "Información de configuración: ñoño, güero, Ángel"
print("Original:", texto_original)

# Alguien guardó el archivo con latin-1 (encoding antiguo de Windows/Linux)
bytes_latin1 = texto_original.encode("latin-1")
print("\nBytes (latin-1):", bytes_latin1[:30], "...")
# Out:
# Original: Información de configuración: ñoño, güero, Ángel
#
# Bytes (latin-1): b'Informaci\xf3n de configuraci\xf3n: ' ...

# %%
# El problema: otro sistema lee esos bytes asumiendo que son UTF-8
# UTF-8 espera secuencias de bytes distintas para caracteres especiales
try:
    texto_mal = bytes_latin1.decode("utf-8")
    print("Leído como UTF-8:", texto_mal)
except UnicodeDecodeError as e:
    print(f"Error al decodificar como UTF-8: {e}")
    print("\nCon errors='replace':")
    texto_mal = bytes_latin1.decode("utf-8", errors="replace")
    print(texto_mal)
# Out:
# Error al decodificar como UTF-8: 'utf-8' codec can't decode byte 0xf3 in position 9: invalid continuation byte
#
# Con errors='replace':
# Informaci�n de configuraci�n: �o�o, g�ero, �ngel

# %%
# Mojibake "exitoso": latin-1 codificado, leído como cp1252
# cp1252 puede leer todos los bytes de latin-1 sin error, pero interpreta diferente
bytes_mojibake = "café con ñ".encode("latin-1")

mojibake = bytes_mojibake.decode("cp500", errors="replace")  # encoding distinto
print("Mojibake:", mojibake)
print()

# La solución: decodificar con el encoding correcto
correcto = bytes_mojibake.decode("latin-1")
print("Correcto:", correcto)
# Out:
# Mojibake: Ä/ÃZÄ?>1
#
# Correcto: café con ñ

# %% [markdown]
# ### Leyendo CSV con encoding específico

# %%
# Simular un CSV guardado en latin-1
csv_content = "nombre,ciudad\nJosé,Mérida\nÁngel,Querétaro\nñoño,Campeche"

# Guardarlo como bytes latin-1 (lo que haría un sistema Windows antiguo)
csv_bytes_latin1 = csv_content.encode("latin-1")

# Leer con el encoding correcto
df_lat = pd.read_csv(io.BytesIO(csv_bytes_latin1), encoding="latin-1")
print("Con encoding='latin-1':")
print(df_lat)
print()
# Out:
# Con encoding='latin-1':
#   nombre     ciudad
# 0   José     Mérida
# 1  Ángel  Querétaro
# 2   ñoño   Campeche

# %%
# ¿Qué pasa si usas el encoding incorrecto?
try:
    df_mal = pd.read_csv(io.BytesIO(csv_bytes_latin1), encoding="utf-8")
    print("Con encoding='utf-8' (incorrecto):")
    print(df_mal)
except UnicodeDecodeError as e:
    print(f"Error esperado: {e}")
    print()
    # pandas tiene encoding_errors= para manejar esto
    df_fallback = pd.read_csv(
        io.BytesIO(csv_bytes_latin1),
        encoding="utf-8",
        encoding_errors="replace"  # reemplaza bytes inválidos con '?'
    )
    print("Con encoding_errors='replace':")
    print(df_fallback)
# Out:
# Error esperado: 'utf-8' codec can't decode byte 0xe9 in position 17: invalid continuation byte
#
# Con encoding_errors='replace':
#   nombre     ciudad
# 0   Jos�     M�rida
# 1  �ngel  Quer�taro
# 2   �o�o   Campeche

# %% [markdown]
# ### Auto-detección de encoding con chardet
#
# Cuando no sabes qué encoding tiene un archivo, `chardet` puede adivinar analizando los patrones de bytes. No es perfecto — da una probabilidad (confidence) — pero es el punto de partida.

# %%
# Detectar encoding de un archivo desconocido
# En producción leerías con 'rb' desde disco: open('archivo.csv', 'rb')
archivo_misterioso = csv_content.encode("latin-1")

resultado = chardet.detect(archivo_misterioso)
print(resultado)
# Ejemplo de salida: {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# Out:
# {'encoding': 'WINDOWS-1252', 'confidence': 0.7801813977740097, 'language': 'Spanish'}

# %%
# Usar el encoding detectado automáticamente
encoding_detectado = resultado["encoding"]
confianza = resultado["confidence"]
print(f"Encoding detectado: {encoding_detectado} (confianza: {confianza:.0%})")

# En código real, podrías poner un umbral de confianza
if confianza > 0.7:
    df_auto = pd.read_csv(io.BytesIO(archivo_misterioso), encoding=encoding_detectado)
    print("\nDataFrame leído con encoding auto-detectado:")
    print(df_auto)
else:
    print("Confianza baja — revisar manualmente")
# Out:
# Encoding detectado: WINDOWS-1252 (confianza: 78%)
#
# DataFrame leído con encoding auto-detectado:
#   nombre     ciudad
# 0   José     Mérida
# 1  Ángel  Querétaro
# 2   ñoño   Campeche

# %% [markdown]
# ### charset_normalizer como alternativa
#
# `charset_normalizer` es una alternativa más moderna a chardet, con mejor precisión en algunos casos. Ya viene incluida con `requests`.

# %%
# charset_normalizer tiene una interfaz diferente — devuelve un objeto Results
results = from_bytes(archivo_misterioso)

# best() da el match con mayor confidence
mejor = results.best()
print(f"Encoding detectado: {mejor.encoding}")
print(f"Confianza: {mejor.chaos:.3f}")
print(f"Texto decodificado: {str(mejor)[:50]}...")
# Out:
# Encoding detectado: cp1250
# Confianza: 0.000
# Texto decodificado: nombre,ciudad
# José,Mérida
# Ángel,Querétaro
# ńońo,Cam...

# %% [markdown]
# ### El BOM de UTF-8 (utf-8-sig)
#
# Excel en Windows guarda archivos CSV con **BOM** (Byte Order Mark): 3 bytes invisibles al inicio del archivo (`\xef\xbb\xbf`). Si lees ese archivo como `utf-8` normal, el nombre de la primera columna tendrá esos bytes invisibles al inicio — un bug que puede ser muy difícil de encontrar.

# %%
# Simular un CSV guardado por Excel con BOM
BOM = b"\xef\xbb\xbf"  # los 3 bytes invisibles que Excel agrega
contenido_csv = b"nombre,edad,ciudad\nAna,28,CDMX\nLuis,34,GDL"
csv_con_bom = BOM + contenido_csv

print(f"Primeros 10 bytes del archivo: {csv_con_bom[:10]}")
print(f"BOM visible: {csv_con_bom[:3] == BOM}")
# Out:
# Primeros 10 bytes del archivo: b'\xef\xbb\xbfnombre,'
# BOM visible: True

# %%
# %config Completer.use_jedi = False

# %%
# El bug: leer como utf-8 normal
df_bom_mal = pd.read_csv(io.BytesIO(csv_con_bom), encoding="utf-8")
print("Columnas con utf-8:", df_bom_mal.columns.tolist())
print("¿Primera columna tiene BOM?", df_bom_mal.columns[0].startswith("\ufeff"))
print()

# Esto causa errores silenciosos: df['nombre'] funciona, df_bom_mal['nombre'] falla
try:
    _ = df_bom_mal["nombre"]
    print("Acceso a 'nombre' exitoso")
except KeyError:
    print("KeyError: 'nombre' no existe — la columna tiene el BOM en su nombre")
# Out:
# Columnas con utf-8: ['nombre', 'edad', 'ciudad']
# ¿Primera columna tiene BOM? False
#
# Acceso a 'nombre' exitoso

# %%
# La solución: utf-8-sig elimina el BOM automáticamente
df_bom_ok = pd.read_csv(io.BytesIO(csv_con_bom), encoding="utf-8-sig")
print("Columnas con utf-8-sig:", df_bom_ok.columns.tolist())
print()
df_bom_ok
# Out:
# Columnas con utf-8-sig: ['nombre', 'edad', 'ciudad']
#   nombre  edad ciudad
# 0    Ana    28   CDMX
# 1   Luis    34    GDL

# %% [markdown]
# 💡 **Prueba esto:** abre un archivo en Excel en Windows y guárdalo como CSV. Luego verifica sus primeros 3 bytes en Python — casi siempre verás el BOM.

# %% [markdown]
# ### Ejercicio 2
#
# Tienes un archivo con encoding desconocido. Completa el código para:
# 1. Detectar el encoding con chardet
# 2. Leer el CSV con el encoding correcto
# 3. Verificar que los acentos se ven bien

# %%
# Archivo "desconocido" — no sabes su encoding
archivo_ej2 = "país,población,región\nMéxico,130000000,América\nEspaña,47000000,Europa".encode("cp1252")

# 1. Detecta el encoding
deteccion = chardet.detect(archivo_ej2)
print(f"Encoding detectado: {deteccion['encoding']} (confianza: {deteccion['confidence']:.0%})")

# 2. Lee el CSV con el encoding detectado
df_ej2 = pd.read_csv(
    io.BytesIO(archivo_ej2),
    encoding=deteccion["encoding"] # ... usa el encoding detectado
)

# 3. Verifica los acentos
print(df_ej2)
# Out:
# Encoding detectado: WINDOWS-1252 (confianza: 82%)
#      país  población   región
# 0  México  130000000  América
# 1  España   47000000   Europa

# %% [markdown]
# <details>
# <summary>Ver solución</summary>
#
# ```python
# deteccion = chardet.detect(archivo_ej2)
# print(f"Encoding detectado: {deteccion['encoding']} (confianza: {deteccion['confidence']:.0%})")
#
# df_ej2 = pd.read_csv(
#     io.BytesIO(archivo_ej2),
#     encoding=deteccion["encoding"]
# )
# print(df_ej2)
# ```
# </details>

# %% [markdown]
# ---
#
# ## Sección 3: JSON — del módulo nativo a pandas
#
# ### El módulo `json` nativo de Python
#
# Antes de llegar a pandas, conviene saber qué hace Python con JSON directamente. `json.loads()` convierte un string JSON a objetos Python, `json.dumps()` hace lo inverso.

# %%
# json.loads: string → objeto Python
json_str = '{"nombre": "Ana", "edad": 28, "activa": true}'
objeto = json.loads(json_str)
print(type(objeto), objeto)
print(f"nombre: {objeto['nombre']}, tipo: {type(objeto['nombre'])}")
# Out:
# <class 'dict'> {'nombre': 'Ana', 'edad': 28, 'activa': True}
# nombre: Ana, tipo: <class 'str'>

# %%
# json.dumps: objeto Python → string JSON
datos = {"usuarios": ["Ana", "Luis"], "total": 2, "activo": True}
json_formateado = json.dumps(datos, indent=2, ensure_ascii=False)
print(json_formateado)
# ensure_ascii=False es clave para que los acentos no se escapen como \u00e1
# Out:
# {
#   "usuarios": [
#     "Ana",
#     "Luis"
#   ],
#   "total": 2,
#   "activo": true
# }

# %% [markdown]
# ### JSON plano → DataFrame directo
#
# Cuando el JSON es un array de objetos con la misma estructura, `pd.DataFrame()` lo convierte directamente.

# %%
# Array de objetos planos — la estructura más amigable con pandas
json_plano = [
    {"id": 1, "nombre": "Ana", "score": 8.5},
    {"id": 2, "nombre": "Luis", "score": 7.2},
    {"id": 3, "nombre": "María", "score": 9.1},
]

# pd.DataFrame() entiende directamente una lista de dicts
df_plano = pd.DataFrame(json_plano)
df_plano
# Out:
#    id nombre  score
# 0   1    Ana    8.5
# 1   2   Luis    7.2
# 2   3  María    9.1

# %% [markdown]
# ### JSON anidado — el caso real de APIs
#
# Las APIs rara vez devuelven JSON plano. Normalmente hay estructuras anidadas: objetos dentro de objetos, arrays dentro de objetos. `pd.json_normalize()` es la función clave para aplanar estas estructuras.

# %%
# Estructura típica de respuesta de API: objeto raíz con array de registros
data_anidada = {
    "status": "ok",
    "total": 3,
    "usuarios": [
        {
            "id": 1,
            "nombre": "Ana",
            "direccion": {"ciudad": "CDMX", "cp": "06600", "estado": "CDMX"},
            "suscripcion": "premium"
        },
        {
            "id": 2,
            "nombre": "Luis",
            "direccion": {"ciudad": "Guadalajara", "cp": "44100", "estado": "JAL"},
            "suscripcion": "free",
            "verified": True
        },
        {
            "id": 3,
            "nombre": "María",
            "direccion": {"ciudad": "Monterrey", "cp": "64000", "estado": "NL"},
            "suscripcion": "premium"
        },
    ]
}

# %%
# Sin json_normalize: el dict 'direccion' queda como un objeto en la columna
df_sin_normalizar = pd.DataFrame(data_anidada["usuarios"])
print("Sin normalizar:")
print(df_sin_normalizar)
print(f"\nTipo de 'direccion': {type(df_sin_normalizar['direccion'][0])}")
# Out:
# Sin normalizar:
#    id nombre                                          direccion suscripcion
# 0   1    Ana  {'ciudad': 'CDMX', 'cp': '06600', 'estado': 'C...     premium
# 1   2   Luis  {'ciudad': 'Guadalajara', 'cp': '44100', 'esta...        free
# 2   3  María  {'ciudad': 'Monterrey', 'cp': '64000', 'estado...     premium
#
# Tipo de 'direccion': <class 'dict'>

# %%
# json_normalize aplana la estructura anidada en columnas separadas
# record_path: dónde están los registros que quiero como filas
# meta: campos del nivel superior que quiero conservar como columnas
df_normalizado = pd.json_normalize(
    data_anidada,
    record_path="usuarios",
    meta=["status", "total"]  # campos del objeto raíz que queremos conservar
)
df_normalizado
# Out:
#    id nombre suscripcion direccion.ciudad direccion.cp direccion.estado  \
# 0   1    Ana     premium             CDMX        06600             CDMX
# 1   2   Luis        free      Guadalajara        44100              JAL
# 2   3  María     premium        Monterrey        64000               NL
#
#   status total
# 0     ok     3
# 1     ok     3
# 2     ok     3

# %%
# Nota: json_normalize usa '.' como separador para campos anidados
# direccion.ciudad, direccion.cp, direccion.estado
# Puedes cambiarlo con sep=
df_sep = pd.json_normalize(
    data_anidada["usuarios"],  # directamente el array de usuarios
    sep="_"  # ahora serán: direccion_ciudad, direccion_cp, etc.
)
print("Columnas con sep='_':")
print(df_sep.columns.tolist())
df_sep.head(2)
# Out:
# Columnas con sep='_':
# ['id', 'nombre', 'suscripcion', 'direccion_ciudad', 'direccion_cp', 'direccion_estado', 'verified']
#    id nombre suscripcion direccion_ciudad direccion_cp direccion_estado  \
# 0   1    Ana     premium             CDMX        06600             CDMX
# 1   2   Luis        free      Guadalajara        44100              JAL
#
#   verified
# 0      NaN
# 1     True

# %% [markdown]
# 💡 **Prueba esto:** agrega un campo extra al primer usuario que no existe en los demás, por ejemplo `"verified": true`. ¿Qué hace `json_normalize` con los valores faltantes en los otros registros?

# %% [markdown]
# ### `pd.read_json()` — cuándo usarlo
#
# `pd.read_json()` es conveniente para JSON con formato estándar (arrays de objetos). El parámetro `orient=` le dice a pandas cómo está estructurado el JSON.

# %%
# orient='records': [{col1: val, col2: val}, ...] — el más común de APIs
json_records = json.dumps([
    {"nombre": "Ana", "score": 8.5},
    {"nombre": "Luis", "score": 7.2}
])
df_records = pd.read_json(io.StringIO(json_records), orient="records")
print("orient='records':")
print(df_records)
# Out:
# orient='records':
#   nombre  score
# 0    Ana    8.5
# 1   Luis    7.2

# %%
# orient='split': {"columns": [...], "index": [...], "data": [[...]]} 
# — compacto, útil para transferir DataFrames
json_split = json.dumps({
    "columns": ["nombre", "score"],
    "index": [0, 1],
    "data": [["Ana", 8.5], ["Luis", 7.2]]
})
df_split = pd.read_json(io.StringIO(json_split), orient="split")
print("orient='split':")
print(df_split)
# Out:
# orient='split':
#   nombre  score
# 0    Ana    8.5
# 1   Luis    7.2

# %%
# orient='columns': {col: {index: value}} — el default de pandas to_json()
json_columns = json.dumps({
    "nombre": {"0": "Ana", "1": "Luis"},
    "score": {"0": 8.5, "1": 7.2}
})
df_columns = pd.read_json(io.StringIO(json_columns), orient="columns")
print("orient='columns':")
print(df_columns)
# Out:
# orient='columns':
#   nombre  score
# 0    Ana    8.5
# 1   Luis    7.2

# %% [markdown]
# ### Manejo de errores en JSON
#
# Los JSON de APIs a veces tienen campos faltantes o tipos inconsistentes. Vale la pena manejar estos casos explícitamente.

# %%
# JSON con estructura inconsistente — campo que a veces es string, a veces int
json_inconsistente = [
    {"id": 1, "valor": "100"},
    {"id": 2, "valor": 200},      # int en vez de string
    {"id": 3},                     # campo 'valor' ausente
    {"id": 4, "valor": None},      # null explícito
]

# pd.DataFrame maneja estos casos con NaN para valores ausentes
df_incons = pd.DataFrame(json_inconsistente)
print(df_incons)
print("\nTipos:", df_incons.dtypes.to_dict())
# Out:
#    id valor
# 0   1   100
# 1   2   200
# 2   3   NaN
# 3   4  None
#
# Tipos: {'id': dtype('int64'), 'valor': dtype('O')}

# %%
# Para JSON malformado, try/except es más explícito que errors='ignore'
json_malo = '{"nombre": "Ana", "edad": }'

try:
    datos = json.loads(json_malo)
    df_malo = pd.DataFrame([datos])
except json.JSONDecodeError as e:
    print(f"JSON malformado en posición {e.pos}: {e.msg}")
    print("Contexto:", json_malo[max(0, e.pos-10):e.pos+10])
# Out:
# JSON malformado en posición 26: Expecting value
# Contexto: , "edad": }

# %% [markdown]
# ### Ejercicio 3
#
# Dada la siguiente estructura JSON de una API de pedidos, normalízala en un DataFrame donde cada fila sea un producto, conservando `id_pedido` y `fecha` como columnas adicionales.

# %%
pedidos_api = {
    "pedidos": [
        {
            "id_pedido": "P001",
            "fecha": "2026-03-01",
            "productos": [
                {"sku": "LAP-001", "nombre": "Laptop", "cantidad": 1, "precio": 22000},
                {"sku": "MOU-001", "nombre": "Mouse", "cantidad": 2, "precio": 350},
            ]
        },
        {
            "id_pedido": "P002",
            "fecha": "2026-03-02",
            "productos": [
                {"sku": "MON-001", "nombre": "Monitor", "cantidad": 1, "precio": 8500},
            ]
        }
    ]
}

# Tu solución: usa pd.json_normalize() con record_path y meta
df_ej3 =pd.json_normalize(
    pedidos_api,
    record_path=["pedidos", "productos"],
    meta=[["pedidos", "id_pedido"], ["pedidos", "fecha"]]
)
df_ej3
# Out:
#        sku   nombre  cantidad  precio pedidos.id_pedido pedidos.fecha
# 0  LAP-001   Laptop         1   22000              P001    2026-03-01
# 1  MOU-001    Mouse         2     350              P001    2026-03-01
# 2  MON-001  Monitor         1    8500              P002    2026-03-02

# %% [markdown]
# <details>
# <summary>Ver solución</summary>
#
# ```python
# df_ej3 = pd.json_normalize(
#     pedidos_api,
#     record_path=["pedidos", "productos"],
#     meta=[["pedidos", "id_pedido"], ["pedidos", "fecha"]]
# )
# df_ej3
# ```
# </details>

# %% [markdown]
# ---
#
# ## Sección 4: Parquet — acceso rápido a columnas
#
# Parquet es un formato columnar binario: eficiente en almacenamiento y muy rápido para leer columnas específicas. Ya vimos su comparación con CSV en el módulo 12. Aquí solo el workflow esencial.

# %%
# Crear un DataFrame de ejemplo para guardar
import tempfile, os

df_origen = pd.DataFrame({
    "id": range(1000),
    "nombre": [f"usuario_{i}" for i in range(1000)],
    "score": np.random.uniform(0, 10, 1000),
    "categoria": np.random.choice(["A", "B", "C"], 1000),
    "fecha": pd.date_range("2026-01-01", periods=1000, freq="h")
})

# Guardar como Parquet con pyarrow como engine
ruta_parquet = os.path.join(tempfile.gettempdir(), "ejemplo.parquet")
df_origen.to_parquet(ruta_parquet, engine="pyarrow", index=False)
print(f"Guardado en: {ruta_parquet}")
print(f"Tamaño: {os.path.getsize(ruta_parquet):,} bytes")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/compat/_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1397     name = _resolve_name(name, package, level)
# -> 1398 return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1370     if module is _NEEDS_LOADING:
# -> 1371         return _find_and_load_unlocked(name, import_)
#    1373 # Optimization: only call _bootstrap._lock_unlock_module() if
#    1374 # module.__spec__._initializing is True.
#    1375 # NOTE: because of this, initializing must be set *before*
#    1376 # putting the new module in sys.modules.
#
# File <frozen importlib._bootstrap>:1335, in _find_and_load_unlocked(name, import_)
#    1334 if spec is None:
# -> 1335     raise ModuleNotFoundError(f'{_ERR_MSG_PREFIX}{name!r}', name=name)
#    1336 else:
#
# ModuleNotFoundError: No module named 'pyarrow'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[61], line 14
#      12 # Guardar como Parquet con pyarrow como engine
#      13 ruta_parquet = os.path.join(tempfile.gettempdir(), "ejemplo.parquet")
# ---> 14 df_origen.to_parquet(ruta_parquet, engine="pyarrow", index=False)
#      15 print(f"Guardado en: {ruta_parquet}")
#      16 print(f"Tamaño: {os.path.getsize(ruta_parquet):,} bytes")
#
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/core/frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)   3131 >>> content = f.read()
#    3132 """
#    3133 from pandas.io.parquet import to_parquet
# -> 3135 return to_parquet(
#    3136     self,
#    3137     path,
#    3138     engine,
#    3139     compression=compression,
#    3140     index=index,
#    3141     partition_cols=partition_cols,
#    3142     storage_options=storage_options,
#    3143     filesystem=filesystem,
#    3144     **kwargs,
#    3145 )
#
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/io/parquet.py:486, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     484 if isinstance(partition_cols, str):
#     485     partition_cols = [partition_cols]
# --> 486 impl = get_engine(engine)
#     488 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     490 impl.write(
#     491     df,
#     492     path_or_buf,
#    (...)    498     **kwargs,
#     499 )
#
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/io/parquet.py:79, in get_engine(engine)
#      68     raise ImportError(
#      69         "Unable to find a usable engine; "
#      70         "tried using: 'pyarrow', 'fastparquet'.\n"
#    (...)     75         f"{error_msgs}"
#      76     )
#      78 if engine == "pyarrow":
# ---> 79     return PyArrowImpl()
#      80 elif engine == "fastparquet":
#      81     return FastParquetImpl()
#
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/io/parquet.py:164, in PyArrowImpl.__init__(self)
#     163 def __init__(self) -> None:
# --> 164     import_optional_dependency(
#     165         "pyarrow", extra="pyarrow is required for parquet support."
#     166     )
#     167     import pyarrow.parquet
#     169     # import utils to register the pyarrow extension types
#
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/compat/_optional.py:161, in import_optional_dependency(name, extra, min_version, errors)
#     159 except ImportError as err:
#     160     if errors == "raise":
# --> 161         raise ImportError(msg) from err
#     162     return None
#     164 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: `Import pyarrow` failed. pyarrow is required for parquet support. Use pip or conda to install the pyarrow package.

# %%
# La ventaja de Parquet: leer solo las columnas que necesitas
# En un archivo con millones de filas, esto es órdenes de magnitud más rápido
df_columnas = pd.read_parquet(
    ruta_parquet,
    engine="pyarrow",
    columns=["id", "score", "categoria"]  # solo estas columnas se leen del disco
)
print(f"Forma: {df_columnas.shape}")
print(f"Columnas: {df_columnas.columns.tolist()}")
df_columnas.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/compat/_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1397     name = _resolve_name(name, package, level)
# -> 1398 return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1370     if module is _NEEDS_LOADING:
# -> 1371         return _find_and_load_unlocked(name, import_)
#    1373 # Optimization: only call _bootstrap._lock_unlock_module() if
#    1374 # module.__spec__._initializing is True.
#    1375 # NOTE: because of this, initializing must be set *before*
#    1376 # putting the new module in sys.modules.
#
# File <frozen importlib._bootstrap>:1335, in _find_and_load_unlocked(name, import_)
#    1334 if spec is None:
# -> 1335     raise ModuleNotFoundError(f'{_ERR_MSG_PREFIX}{name!r}', name=name)
#    1336 else:
#
# ModuleNotFoundError: No module named 'pyarrow'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[62], line 3
#       1 # La ventaja de Parquet: leer solo las columnas que necesitas
#       2 # En un archivo con millones de filas, esto es órdenes de magnitud más rápido
# ----> 3 df_columnas = pd.read_parquet(
#       4     ruta_parquet,
#       5     engine="pyarrow",
#       6     columns=["id", "score", "categoria"]  # solo estas columnas se leen del disco
#       7 )
#       8 print(f"Forma: {df_columnas.shape}")
#       9 print(f"Columnas: {df_columnas.columns.tolist()}")
#
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/io/parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
#     673         columns=columns,
#    (...)    679         **kwargs,
#     680     )
#
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/io/parquet.py:79, in get_engine(engine)
#      68     raise ImportError(
#      69         "Unable to find a usable engine; "
#      70         "tried using: 'pyarrow', 'fastparquet'.\n"
#    (...)     75         f"{error_msgs}"
#      76     )
#      78 if engine == "pyarrow":
# ---> 79     return PyArrowImpl()
#      80 elif engine == "fastparquet":
#      81     return FastParquetImpl()
#
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/io/parquet.py:164, in PyArrowImpl.__init__(self)
#     163 def __init__(self) -> None:
# --> 164     import_optional_dependency(
#     165         "pyarrow", extra="pyarrow is required for parquet support."
#     166     )
#     167     import pyarrow.parquet
#     169     # import utils to register the pyarrow extension types
#
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/compat/_optional.py:161, in import_optional_dependency(name, extra, min_version, errors)
#     159 except ImportError as err:
#     160     if errors == "raise":
# --> 161         raise ImportError(msg) from err
#     162     return None
#     164 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: `Import pyarrow` failed. pyarrow is required for parquet support. Use pip or conda to install the pyarrow package.

# %%
# Parquet preserva los tipos — no hay conversión de fechas ni de categorías
print("Tipos originales:", df_origen.dtypes.to_dict())
print()
df_todo = pd.read_parquet(ruta_parquet)
print("Tipos leídos:", df_todo.dtypes.to_dict())

# Limpiar el archivo temporal
os.remove(ruta_parquet)
# Out:
# Tipos originales: {'id': dtype('int64'), 'nombre': <StringDtype(storage='python', na_value=nan)>, 'score': dtype('float64'), 'categoria': <StringDtype(storage='python', na_value=nan)>, 'fecha': dtype('<M8[us]')}
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[63], line 4
#       2 print("Tipos originales:", df_origen.dtypes.to_dict())
#       3 print()
# ----> 4 df_todo = pd.read_parquet(ruta_parquet)
#       5 print("Tipos leídos:", df_todo.dtypes.to_dict())
#       7 # Limpiar el archivo temporal
#
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/io/parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)    518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)    665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
#     673         columns=columns,
#    (...)    679         **kwargs,
#     680     )
#
# File ~/Desktop/fuentes/fdd_p26/.venv/lib/python3.14/site-packages/pandas/io/parquet.py:68, in get_engine(engine)
#      65         except ImportError as err:
#      66             error_msgs += "\n - " + str(err)
# ---> 68     raise ImportError(
#      69         "Unable to find a usable engine; "
#      70         "tried using: 'pyarrow', 'fastparquet'.\n"
#      71         "A suitable version of "
#      72         "pyarrow or fastparquet is required for parquet "
#      73         "support.\n"
#      74         "Trying to import the above resulted in these errors:"
#      75         f"{error_msgs}"
#      76     )
#      78 if engine == "pyarrow":
#      79     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - `Import pyarrow` failed. pyarrow is required for parquet support. Use pip or conda to install the pyarrow package.
#  - `Import fastparquet` failed. fastparquet is required for parquet support. Use pip or conda to install the fastparquet package.

# %% [markdown]
# ---
#
# ## Sección 5: Ejercicio integrador
#
# Este ejercicio combina todo lo visto: CSV con encoding especial, detección automática, corrección de mojibake y normalización de JSON anidado.

# %% [markdown]
# ### Parte 1: CSV con separador `;` y encoding latin-1

# %%
# Simular un CSV exportado desde un sistema legacy en México
csv_legado = (
    "clave;municipio;población;estado\n"
    "01001;Aguascalientes;979884;AGS\n"
    "02001;Ensenada;536091;BC\n"
    "09002;Azcapotzalco;400161;CDMX\n"
    "14039;Guadalajara;1385629;JAL\n"
    "19039;Monterrey;1135512;NL"
)
archivo_legado = csv_legado.encode("latin-1")

# Parte 1a: Lee el CSV con los parámetros correctos
df_municipios = pd.read_csv(
    io.BytesIO(archivo_legado),
    sep=";",
    encoding="latin-1",
    dtype={"clave": str}  # mantener cero inicial
)
print("CSV leído correctamente:")
df_municipios
# Out:
# CSV leído correctamente:
#    clave       municipio  población estado
# 0  01001  Aguascalientes     979884    AGS
# 1  02001        Ensenada     536091     BC
# 2  09002    Azcapotzalco     400161   CDMX
# 3  14039     Guadalajara    1385629    JAL
# 4  19039       Monterrey    1135512     NL

# %% [markdown]
# ### Parte 2: Detección automática de encoding

# %%
# Simular que no sabemos el encoding del archivo
def leer_csv_encoding_desconocido(contenido_bytes):
    """Lee un CSV detectando automáticamente su encoding."""
    # Detectar encoding
    deteccion = chardet.detect(contenido_bytes)
    encoding = deteccion["encoding"]
    confianza = deteccion["confidence"]
    
    print(f"Encoding detectado: {encoding} (confianza: {confianza:.0%})")
    
    # Leer con el encoding detectado, con fallback a latin-1
    try:
        return pd.read_csv(io.BytesIO(contenido_bytes), sep=";", encoding=encoding, dtype={"clave": str})
    except (UnicodeDecodeError, LookupError):
        print("Encoding detectado falló, usando latin-1 como fallback")
        return pd.read_csv(io.BytesIO(contenido_bytes), sep=";", encoding="latin-1", dtype={"clave": str})

df_auto = leer_csv_encoding_desconocido(archivo_legado)
df_auto
# Out:
# Encoding detectado: WINDOWS-1252 (confianza: 69%)
#    clave       municipio  población estado
# 0  01001  Aguascalientes     979884    AGS
# 1  02001        Ensenada     536091     BC
# 2  09002    Azcapotzalco     400161   CDMX
# 3  14039     Guadalajara    1385629    JAL
# 4  19039       Monterrey    1135512     NL

# %% [markdown]
# ### Parte 3: Corrección de mojibake

# %%
# Simular texto con mojibake: se guardó en latin-1 pero alguien lo leyó como cp500
texto_con_acento = "Población de Jalisco: güero y ñoño"
bytes_originales = texto_con_acento.encode("latin-1")

# Mojibake: decodificado con el encoding equivocado
texto_mojibake = bytes_originales.decode("cp500", errors="replace")
print("Con mojibake:", texto_mojibake)
# Out:
# Con mojibake: &?Â%/ÄÑ3>ÀÁ[/%ÑËÄ?ÅÜÁÊ?`1?1?

# %%
# Estrategia de corrección cuando conoces el encoding original
# 1. Re-encodear a bytes con el encoding en que fue leído erróneamente
# 2. Decodificar con el encoding correcto
def corregir_mojibake(texto_mal, encoding_incorrecto, encoding_correcto):
    """Intenta revertir un mojibake conociendo los dos encodings involucrados."""
    try:
        bytes_recuperados = texto_mal.encode(encoding_incorrecto, errors="replace")
        return bytes_recuperados.decode(encoding_correcto, errors="replace")
    except (UnicodeEncodeError, UnicodeDecodeError) as e:
        return f"No se pudo corregir: {e}"

# Alternativa más práctica: si sabes los bytes originales, decodificar directamente
texto_correcto = bytes_originales.decode("latin-1")
print("Texto corregido:", texto_correcto)
print("¿Igual al original?", texto_correcto == texto_con_acento)
# Out:
# Texto corregido: Población de Jalisco: güero y ñoño
# ¿Igual al original? True

# %% [markdown]
# ### Parte 4: Normalizar JSON anidado de una API

# %%
# Respuesta típica de una API de datos municipales
api_respuesta = {
    "version": "2.1",
    "fuente": "INEGI",
    "registros": [
        {
            "clave": "14039",
            "nombre": "Guadalajara",
            "ubicacion": {"estado": "Jalisco", "region": "Occidente", "lat": 20.67, "lon": -103.35},
            "indicadores": {"poblacion": 1385629, "densidad": 9766, "area_km2": 142}
        },
        {
            "clave": "19039",
            "nombre": "Monterrey",
            "ubicacion": {"estado": "Nuevo León", "region": "Noreste", "lat": 25.67, "lon": -100.31},
            "indicadores": {"poblacion": 1135512, "densidad": 6847, "area_km2": 166}
        },
        {
            "clave": "09002",
            "nombre": "Azcapotzalco",
            "ubicacion": {"estado": "CDMX", "region": "Centro", "lat": 19.49, "lon": -99.18},
            "indicadores": {"poblacion": 400161, "densidad": 14720, "area_km2": 27}
        }
    ]
}

# Normalizar: cada registro como fila, campos anidados como columnas
df_api = pd.json_normalize(
    api_respuesta,
    record_path="registros",
    meta=["fuente"],
    sep="_"  # ubicacion_estado, indicadores_poblacion, etc.
)

print("Columnas:", df_api.columns.tolist())
print()
df_api
# Out:
# Columnas: ['clave', 'nombre', 'ubicacion_estado', 'ubicacion_region', 'ubicacion_lat', 'ubicacion_lon', 'indicadores_poblacion', 'indicadores_densidad', 'indicadores_area_km2', 'fuente']
#    clave        nombre ubicacion_estado ubicacion_region  ubicacion_lat  \
# 0  14039   Guadalajara          Jalisco        Occidente          20.67
# 1  19039     Monterrey       Nuevo León          Noreste          25.67
# 2  09002  Azcapotzalco             CDMX           Centro          19.49
#
#    ubicacion_lon  indicadores_poblacion  indicadores_densidad  \
# 0        -103.35                1385629                  9766
# 1        -100.31                1135512                  6847
# 2         -99.18                 400161                 14720
#
#    indicadores_area_km2 fuente
# 0                   142  INEGI
# 1                   166  INEGI
# 2                    27  INEGI

# %%
# Combinar todo: unir el CSV de municipios con la respuesta de API por clave
# Primero aseguramos que clave es string en ambos
df_api["clave"] = df_api["clave"].astype(str)
df_municipios["clave"] = df_municipios["clave"].astype(str)

df_combinado = df_municipios.merge(
    df_api[["clave", "ubicacion_region", "indicadores_densidad"]],
    on="clave",
    how="left"  # left join para no perder municipios sin datos de API
)

df_combinado
# Out:
#    clave       municipio  población estado ubicacion_region  \
# 0  01001  Aguascalientes     979884    AGS              NaN
# 1  02001        Ensenada     536091     BC              NaN
# 2  09002    Azcapotzalco     400161   CDMX           Centro
# 3  14039     Guadalajara    1385629    JAL        Occidente
# 4  19039       Monterrey    1135512     NL          Noreste
#
#    indicadores_densidad
# 0                   NaN
# 1                   NaN
# 2               14720.0
# 3                9766.0
# 4                6847.0

# %% [markdown]
# ---
#
# ## Resumen
#
# | Situación | Solución |
# |---|---|
# | CSV con `;` como separador | `sep=";"` |
# | Archivo sin header | `header=None, names=[...]` |
# | Metadata antes de los datos | `skiprows=N` |
# | Solo algunas columnas | `usecols=["a", "b"]` |
# | Tipos incorrectos / códigos postales | `dtype={"col": str}` |
# | Valores nulos no estándar | `na_values=["." , "ND", "99999"]` |
# | Encoding desconocido | `chardet.detect(bytes)` |
# | Archivo de Excel Windows | `encoding="utf-8-sig"` |
# | JSON plano de API | `pd.DataFrame(lista_de_dicts)` |
# | JSON anidado | `pd.json_normalize(data, record_path=..., meta=...)` |
# | Lectura eficiente de columnas | Parquet + `pd.read_parquet(columns=[...])` |
#
# **Regla de oro:** cuando un archivo no se lee bien, revisa primero el separador y el encoding — el 80% de los problemas de IO vienen de ahí.
